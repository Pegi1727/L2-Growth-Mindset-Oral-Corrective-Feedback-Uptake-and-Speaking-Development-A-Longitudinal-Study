# %% [markdown]
# # نمای کلی داده‌ها
#
# بارگذاری، بررسی ابعاد، انواع داده، مقادیر گمشده و آمار توصیفی.
#
# **Data source:** `Longitudinal_Data_120.csv` (120 participants).

# %%
import pandas as pd
from pathlib import Path
df = pd.read_csv(Path('Longitudinal_Data_120.csv'))
df.head()

# %%
print('Shape:', df.shape)
print('Columns:', df.columns.tolist())
df.info()

# %%
display(df.isna().sum().rename('missing').to_frame())
display(df.describe().T)
